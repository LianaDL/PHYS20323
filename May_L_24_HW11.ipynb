# %% [markdown]
# # PyObject:  Object-oriented programming HW 11

# %% [markdown]
# ## Exercise 1  (from Monday's class)

# %% [markdown]
# 1. Write a ``Particle`` class that can be used to represent a particle with a mass, a 3-d position, and a 3-d velocity.
#
# 2. Write a method that can be used to compute the kinetic energy of the particle
#
# 3. Write a method that takes another particle as an argument and finds the distance between the two particles
#
# 4. Write a method that given a time interval ``dt`` will update the position of the particle to the new position based on the current position and velocity.
#
# 5. Write a ``ChargedParticle`` class that inherits from the ``Particle`` class, but also has an attribute for the charge of the particle.

# %%
import numpy as np
# your solution here

class ChargedParticle(Particle):

    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
        self.mass = mass
        self.x = x
        self.y = y
        self.z = z
        self.vx = vx
        self.vy = vy
        self.vz = vz
        self.charge = charge

# %%
import numpy as np

class Particle:
    def __init__(self, mass, x, y, z, vx, vy, vz):
        self.mass = mass
        self.position = np.array([x, y, z], dtype=float)
        self.velocity = np.array([vx, vy, vz], dtype=float)

    def kinetic_energy(self):
        """Calculate the kinetic energy of the particle."""
        speed_squared = np.dot(self.velocity, self.velocity)
        return 0.5 * self.mass * speed_squared

    def distance_to(self, other):
        """Calculate the distance between this particle and another."""
        if not isinstance(other, Particle):
            raise TypeError("Argument must be an instance of Particle")
        return np.linalg.norm(self.position - other.position)

    def update_position(self, dt):
        """Update the position of the particle given a time interval dt."""
        self.position += self.velocity * dt

class ChargedParticle(Particle):
    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
        super().__init__(mass, x, y, z, vx, vy, vz)
        self.charge = charge

if __name__ == "__main__":
    p1 = Particle(1.0, 0, 0, 0, 1, 1, 1)
    p2 = Particle(2.0, 3, 3, 3, -1, -1, -1)
    cp1 = ChargedParticle(1.5, 0, 0, 0, 0, 0, 1, -1)

    print("Kinetic energy of p1:", p1.kinetic_energy())
    print("Distance between p1 and p2:", p1.distance_to(p2))

    print("Position of p1 before update:", p1.position)
    p1.update_position(2.0)
    print("Position of p1 after update:", p1.position)

    print("Charge of cp1:", cp1.charge)
# Out:
# Kinetic energy of p1: 1.5
# Distance between p1 and p2: 5.196152422706632
# Position of p1 before update: [0. 0. 0.]
# Position of p1 after update: [2. 2. 2.]
# Charge of cp1: -1

# %% [markdown]
# ## Exercise 2  (New)

# %% [markdown]
# 6. Write a method that can be used to see if a particle is in the same place (e.g., find_seperation < 0.25).  If there are two ChargedParticles in the same place make a "simple" (*not correct physics*) "interaction". (__have the code print "interaction"__).
#
#     a. If the charges are opposite, make them "combine", set both velocities to zero and set their charge to zero, and print "merge".
#
#     b. Else, make the particles "repel", to do:
#
#         multiply each "self" velocity and  by (-1 * (self.charge+other.charge) * (self.mass/other.mass))
#
#         multiply each "other" velocity by (-1 * (self.charge+other.charge) * (other.mass/self.mass))
#
#     e.g., reversing it's velocity, and print "repel". __(Again this is bad physics, but we are focusing on coding so play along.)__
#
#
# 7. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (1,1,1) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = -0.5).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.
#
#
# 8. To test the above, write a code with two particles starting:
#
#         P1 at (x,y,z) = (-5,-5,-5) with (vx,vy,vz) = (2,2,2) and (charge = 0.5)
#
#         P2 at (x,y,z) = (5,5,5) with (vx,vy,vz) = (-1,-1,-1) and (charge = 2.0).
#
#     Use your dt time interval to move the particles in 0.05 time steps for 300 steps, and print the current poition and velocity of each particle at each time step.

# %%
import numpy as np

class Particle:
    def __init__(self, mass, x, y, z, vx, vy, vz):
        self.mass = mass
        self.position = np.array([x, y, z], dtype=float)
        self.velocity = np.array([vx, vy, vz], dtype=float)

    def kinetic_energy(self):
        """Calculate the kinetic energy of the particle."""
        speed_squared = np.dot(self.velocity, self.velocity)
        return 0.5 * self.mass * speed_squared

    def distance_to(self, other):
        """Calculate the distance between this particle and another."""
        if not isinstance(other, Particle):
            raise TypeError("Argument must be an instance of Particle")
        return np.linalg.norm(self.position - other.position)

    def update_position(self, dt):
        """Update the position of the particle given a time interval dt."""
        self.position += self.velocity * dt


class ChargedParticle(Particle):
    def __init__(self, mass, x, y, z, vx, vy, vz, charge):
        super().__init__(mass, x, y, z, vx, vy, vz)
        self.charge = charge

    def check_interaction(self, other):
        """Check for interaction between two charged particles."""
        if not isinstance(other, ChargedParticle):
            raise TypeError("Other particle must be an instance of ChargedParticle")

        if self.distance_to(other) < 0.25:
            print("Interaction")
            if self.charge * other.charge < 0: 
                self.velocity = np.zeros(3)
                other.velocity = np.zeros(3)
                self.charge = 0
                other.charge = 0
                print("Merge")
            else: 
                charge_sum = self.charge + other.charge
                self.velocity *= -1 * charge_sum * (self.mass / other.mass)
                other.velocity *= -1 * charge_sum * (other.mass / self.mass)
                print("Repel")


def run_simulation(p1, p2, dt, steps):
    for step in range(steps):
        p1.update_position(dt)
        p2.update_position(dt)
        p1.check_interaction(p2)
        print(f"Step {step + 1}:")
        print(f"  P1 Position: {p1.position}, Velocity: {p1.velocity}")
        print(f"  P2 Position: {p2.position}, Velocity: {p2.velocity}")
        print("-" * 50)


p1 = ChargedParticle(1.0, -5, -5, -5, 1, 1, 1, 0.5)
p2 = ChargedParticle(1.0, 5, 5, 5, -1, -1, -1, -0.5)
print("Test 1: Opposite Charges")
run_simulation(p1, p2, 0.05, 300)

p1 = ChargedParticle(1.0, -5, -5, -5, 2, 2, 2, 0.5)
p2 = ChargedParticle(1.0, 5, 5, 5, -1, -1, -1, 2.0)
print("\nTest 2: Same Charges")
run_simulation(p1, p2, 0.05, 300)
# Out:
# Test 1: Opposite Charges
# Step 1:
#   P1 Position: [-4.95 -4.95 -4.95], Velocity: [1. 1. 1.]
#   P2 Position: [4.95 4.95 4.95], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 2:
#   P1 Position: [-4.9 -4.9 -4.9], Velocity: [1. 1. 1.]
#   P2 Position: [4.9 4.9 4.9], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 3:
#   P1 Position: [-4.85 -4.85 -4.85], Velocity: [1. 1. 1.]
#   P2 Position: [4.85 4.85 4.85], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 4:
#   P1 Position: [-4.8 -4.8 -4.8], Velocity: [1. 1. 1.]
#   P2 Position: [4.8 4.8 4.8], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 5:
#   P1 Position: [-4.75 -4.75 -4.75], Velocity: [1. 1. 1.]
#   P2 Position: [4.75 4.75 4.75], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 6:
#   P1 Position: [-4.7 -4.7 -4.7], Velocity: [1. 1. 1.]
#   P2 Position: [4.7 4.7 4.7], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 7:
#   P1 Position: [-4.65 -4.65 -4.65], Velocity: [1. 1. 1.]
#   P2 Position: [4.65 4.65 4.65], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 8:
#   P1 Position: [-4.6 -4.6 -4.6], Velocity: [1. 1. 1.]
#   P2 Position: [4.6 4.6 4.6], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 9:
#   P1 Position: [-4.55 -4.55 -4.55], Velocity: [1. 1. 1.]
#   P2 Position: [4.55 4.55 4.55], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 10:
#   P1 Position: [-4.5 -4.5 -4.5], Velocity: [1. 1. 1.]
#   P2 Position: [4.5 4.5 4.5], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 11:
#   P1 Position: [-4.45 -4.45 -4.45], Velocity: [1. 1. 1.]
#   P2 Position: [4.45 4.45 4.45], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 12:
#   P1 Position: [-4.4 -4.4 -4.4], Velocity: [1. 1. 1.]
#   P2 Position: [4.4 4.4 4.4], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 13:
#   P1 Position: [-4.35 -4.35 -4.35], Velocity: [1. 1. 1.]
#   P2 Position: [4.35 4.35 4.35], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 14:
#   P1 Position: [-4.3 -4.3 -4.3], Velocity: [1. 1. 1.]
#   P2 Position: [4.3 4.3 4.3], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 15:
#   P1 Position: [-4.25 -4.25 -4.25], Velocity: [1. 1. 1.]
#   P2 Position: [4.25 4.25 4.25], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 16:
#   P1 Position: [-4.2 -4.2 -4.2], Velocity: [1. 1. 1.]
#   P2 Position: [4.2 4.2 4.2], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 17:
#   P1 Position: [-4.15 -4.15 -4.15], Velocity: [1. 1. 1.]
#   P2 Position: [4.15 4.15 4.15], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 18:
#   P1 Position: [-4.1 -4.1 -4.1], Velocity: [1. 1. 1.]
#   P2 Position: [4.1 4.1 4.1], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 19:
#   P1 Position: [-4.05 -4.05 -4.05], Velocity: [1. 1. 1.]
#   P2 Position: [4.05 4.05 4.05], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 20:
#   P1 Position: [-4. -4. -4.], Velocity: [1. 1. 1.]
#   P2 Position: [4. 4. 4.], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 21:
#   P1 Position: [-3.95 -3.95 -3.95], Velocity: [1. 1. 1.]
#   P2 Position: [3.95 3.95 3.95], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 22:
#   P1 Position: [-3.9 -3.9 -3.9], Velocity: [1. 1. 1.]
#   P2 Position: [3.9 3.9 3.9], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 23:
#   P1 Position: [-3.85 -3.85 -3.85], Velocity: [1. 1. 1.]
#   P2 Position: [3.85 3.85 3.85], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 24:
#   P1 Position: [-3.8 -3.8 -3.8], Velocity: [1. 1. 1.]
#   P2 Position: [3.8 3.8 3.8], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 25:
#   P1 Position: [-3.75 -3.75 -3.75], Velocity: [1. 1. 1.]
#   P2 Position: [3.75 3.75 3.75], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 26:
#   P1 Position: [-3.7 -3.7 -3.7], Velocity: [1. 1. 1.]
#   P2 Position: [3.7 3.7 3.7], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 27:
#   P1 Position: [-3.65 -3.65 -3.65], Velocity: [1. 1. 1.]
#   P2 Position: [3.65 3.65 3.65], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 28:
#   P1 Position: [-3.6 -3.6 -3.6], Velocity: [1. 1. 1.]
#   P2 Position: [3.6 3.6 3.6], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 29:
#   P1 Position: [-3.55 -3.55 -3.55], Velocity: [1. 1. 1.]
#   P2 Position: [3.55 3.55 3.55], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 30:
#   P1 Position: [-3.5 -3.5 -3.5], Velocity: [1. 1. 1.]
#   P2 Position: [3.5 3.5 3.5], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 31:
#   P1 Position: [-3.45 -3.45 -3.45], Velocity: [1. 1. 1.]
#   P2 Position: [3.45 3.45 3.45], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 32:
#   P1 Position: [-3.4 -3.4 -3.4], Velocity: [1. 1. 1.]
#   P2 Position: [3.4 3.4 3.4], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 33:
#   P1 Position: [-3.35 -3.35 -3.35], Velocity: [1. 1. 1.]
#   P2 Position: [3.35 3.35 3.35], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 34:
#   P1 Position: [-3.3 -3.3 -3.3], Velocity: [1. 1. 1.]
#   P2 Position: [3.3 3.3 3.3], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 35:
#   P1 Position: [-3.25 -3.25 -3.25], Velocity: [1. 1. 1.]
#   P2 Position: [3.25 3.25 3.25], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 36:
#   P1 Position: [-3.2 -3.2 -3.2], Velocity: [1. 1. 1.]
#   P2 Position: [3.2 3.2 3.2], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 37:
#   P1 Position: [-3.15 -3.15 -3.15], Velocity: [1. 1. 1.]
#   P2 Position: [3.15 3.15 3.15], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 38:
#   P1 Position: [-3.1 -3.1 -3.1], Velocity: [1. 1. 1.]
#   P2 Position: [3.1 3.1 3.1], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 39:
#   P1 Position: [-3.05 -3.05 -3.05], Velocity: [1. 1. 1.]
#   P2 Position: [3.05 3.05 3.05], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 40:
#   P1 Position: [-3. -3. -3.], Velocity: [1. 1. 1.]
#   P2 Position: [3. 3. 3.], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 41:
#   P1 Position: [-2.95 -2.95 -2.95], Velocity: [1. 1. 1.]
#   P2 Position: [2.95 2.95 2.95], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 42:
#   P1 Position: [-2.9 -2.9 -2.9], Velocity: [1. 1. 1.]
#   P2 Position: [2.9 2.9 2.9], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 43:
#   P1 Position: [-2.85 -2.85 -2.85], Velocity: [1. 1. 1.]
#   P2 Position: [2.85 2.85 2.85], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 44:
#   P1 Position: [-2.8 -2.8 -2.8], Velocity: [1. 1. 1.]
#   P2 Position: [2.8 2.8 2.8], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 45:
#   P1 Position: [-2.75 -2.75 -2.75], Velocity: [1. 1. 1.]
#   P2 Position: [2.75 2.75 2.75], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 46:
#   P1 Position: [-2.7 -2.7 -2.7], Velocity: [1. 1. 1.]
#   P2 Position: [2.7 2.7 2.7], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 47:
#   P1 Position: [-2.65 -2.65 -2.65], Velocity: [1. 1. 1.]
#   P2 Position: [2.65 2.65 2.65], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 48:
#   P1 Position: [-2.6 -2.6 -2.6], Velocity: [1. 1. 1.]
#   P2 Position: [2.6 2.6 2.6], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 49:
#   P1 Position: [-2.55 -2.55 -2.55], Velocity: [1. 1. 1.]
#   P2 Position: [2.55 2.55 2.55], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 50:
#   P1 Position: [-2.5 -2.5 -2.5], Velocity: [1. 1. 1.]
#   P2 Position: [2.5 2.5 2.5], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 51:
#   P1 Position: [-2.45 -2.45 -2.45], Velocity: [1. 1. 1.]
#   P2 Position: [2.45 2.45 2.45], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 52:
#   P1 Position: [-2.4 -2.4 -2.4], Velocity: [1. 1. 1.]
#   P2 Position: [2.4 2.4 2.4], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 53:
#   P1 Position: [-2.35 -2.35 -2.35], Velocity: [1. 1. 1.]
#   P2 Position: [2.35 2.35 2.35], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 54:
#   P1 Position: [-2.3 -2.3 -2.3], Velocity: [1. 1. 1.]
#   P2 Position: [2.3 2.3 2.3], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 55:
#   P1 Position: [-2.25 -2.25 -2.25], Velocity: [1. 1. 1.]
#   P2 Position: [2.25 2.25 2.25], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 56:
#   P1 Position: [-2.2 -2.2 -2.2], Velocity: [1. 1. 1.]
#   P2 Position: [2.2 2.2 2.2], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 57:
#   P1 Position: [-2.15 -2.15 -2.15], Velocity: [1. 1. 1.]
#   P2 Position: [2.15 2.15 2.15], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 58:
#   P1 Position: [-2.1 -2.1 -2.1], Velocity: [1. 1. 1.]
#   P2 Position: [2.1 2.1 2.1], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 59:
#   P1 Position: [-2.05 -2.05 -2.05], Velocity: [1. 1. 1.]
#   P2 Position: [2.05 2.05 2.05], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 60:
#   P1 Position: [-2. -2. -2.], Velocity: [1. 1. 1.]
#   P2 Position: [2. 2. 2.], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 61:
#   P1 Position: [-1.95 -1.95 -1.95], Velocity: [1. 1. 1.]
#   P2 Position: [1.95 1.95 1.95], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 62:
#   P1 Position: [-1.9 -1.9 -1.9], Velocity: [1. 1. 1.]
#   P2 Position: [1.9 1.9 1.9], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 63:
#   P1 Position: [-1.85 -1.85 -1.85], Velocity: [1. 1. 1.]
#   P2 Position: [1.85 1.85 1.85], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 64:
#   P1 Position: [-1.8 -1.8 -1.8], Velocity: [1. 1. 1.]
#   P2 Position: [1.8 1.8 1.8], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 65:
#   P1 Position: [-1.75 -1.75 -1.75], Velocity: [1. 1. 1.]
#   P2 Position: [1.75 1.75 1.75], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 66:
#   P1 Position: [-1.7 -1.7 -1.7], Velocity: [1. 1. 1.]
#   P2 Position: [1.7 1.7 1.7], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 67:
#   P1 Position: [-1.65 -1.65 -1.65], Velocity: [1. 1. 1.]
#   P2 Position: [1.65 1.65 1.65], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 68:
#   P1 Position: [-1.6 -1.6 -1.6], Velocity: [1. 1. 1.]
#   P2 Position: [1.6 1.6 1.6], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 69:
#   P1 Position: [-1.55 -1.55 -1.55], Velocity: [1. 1. 1.]
#   P2 Position: [1.55 1.55 1.55], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 70:
#   P1 Position: [-1.5 -1.5 -1.5], Velocity: [1. 1. 1.]
#   P2 Position: [1.5 1.5 1.5], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 71:
#   P1 Position: [-1.45 -1.45 -1.45], Velocity: [1. 1. 1.]
#   P2 Position: [1.45 1.45 1.45], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 72:
#   P1 Position: [-1.4 -1.4 -1.4], Velocity: [1. 1. 1.]
#   P2 Position: [1.4 1.4 1.4], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 73:
#   P1 Position: [-1.35 -1.35 -1.35], Velocity: [1. 1. 1.]
#   P2 Position: [1.35 1.35 1.35], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 74:
#   P1 Position: [-1.3 -1.3 -1.3], Velocity: [1. 1. 1.]
#   P2 Position: [1.3 1.3 1.3], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 75:
#   P1 Position: [-1.25 -1.25 -1.25], Velocity: [1. 1. 1.]
#   P2 Position: [1.25 1.25 1.25], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 76:
#   P1 Position: [-1.2 -1.2 -1.2], Velocity: [1. 1. 1.]
#   P2 Position: [1.2 1.2 1.2], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 77:
#   P1 Position: [-1.15 -1.15 -1.15], Velocity: [1. 1. 1.]
#   P2 Position: [1.15 1.15 1.15], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 78:
#   P1 Position: [-1.1 -1.1 -1.1], Velocity: [1. 1. 1.]
#   P2 Position: [1.1 1.1 1.1], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 79:
#   P1 Position: [-1.05 -1.05 -1.05], Velocity: [1. 1. 1.]
#   P2 Position: [1.05 1.05 1.05], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 80:
#   P1 Position: [-1. -1. -1.], Velocity: [1. 1. 1.]
#   P2 Position: [1. 1. 1.], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 81:
#   P1 Position: [-0.95 -0.95 -0.95], Velocity: [1. 1. 1.]
#   P2 Position: [0.95 0.95 0.95], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 82:
#   P1 Position: [-0.9 -0.9 -0.9], Velocity: [1. 1. 1.]
#   P2 Position: [0.9 0.9 0.9], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 83:
#   P1 Position: [-0.85 -0.85 -0.85], Velocity: [1. 1. 1.]
#   P2 Position: [0.85 0.85 0.85], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 84:
#   P1 Position: [-0.8 -0.8 -0.8], Velocity: [1. 1. 1.]
#   P2 Position: [0.8 0.8 0.8], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 85:
#   P1 Position: [-0.75 -0.75 -0.75], Velocity: [1. 1. 1.]
#   P2 Position: [0.75 0.75 0.75], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 86:
#   P1 Position: [-0.7 -0.7 -0.7], Velocity: [1. 1. 1.]
#   P2 Position: [0.7 0.7 0.7], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 87:
#   P1 Position: [-0.65 -0.65 -0.65], Velocity: [1. 1. 1.]
#   P2 Position: [0.65 0.65 0.65], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 88:
#   P1 Position: [-0.6 -0.6 -0.6], Velocity: [1. 1. 1.]
#   P2 Position: [0.6 0.6 0.6], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 89:
#   P1 Position: [-0.55 -0.55 -0.55], Velocity: [1. 1. 1.]
#   P2 Position: [0.55 0.55 0.55], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 90:
#   P1 Position: [-0.5 -0.5 -0.5], Velocity: [1. 1. 1.]
#   P2 Position: [0.5 0.5 0.5], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 91:
#   P1 Position: [-0.45 -0.45 -0.45], Velocity: [1. 1. 1.]
#   P2 Position: [0.45 0.45 0.45], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 92:
#   P1 Position: [-0.4 -0.4 -0.4], Velocity: [1. 1. 1.]
#   P2 Position: [0.4 0.4 0.4], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 93:
#   P1 Position: [-0.35 -0.35 -0.35], Velocity: [1. 1. 1.]
#   P2 Position: [0.35 0.35 0.35], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 94:
#   P1 Position: [-0.3 -0.3 -0.3], Velocity: [1. 1. 1.]
#   P2 Position: [0.3 0.3 0.3], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 95:
#   P1 Position: [-0.25 -0.25 -0.25], Velocity: [1. 1. 1.]
#   P2 Position: [0.25 0.25 0.25], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 96:
#   P1 Position: [-0.2 -0.2 -0.2], Velocity: [1. 1. 1.]
#   P2 Position: [0.2 0.2 0.2], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 97:
#   P1 Position: [-0.15 -0.15 -0.15], Velocity: [1. 1. 1.]
#   P2 Position: [0.15 0.15 0.15], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Step 98:
#   P1 Position: [-0.1 -0.1 -0.1], Velocity: [1. 1. 1.]
#   P2 Position: [0.1 0.1 0.1], Velocity: [-1. -1. -1.]
# --------------------------------------------------
# Interaction
# Merge
# Step 99:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 100:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 101:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 102:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 103:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 104:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 105:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 106:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 107:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 108:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 109:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 110:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 111:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 112:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 113:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 114:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 115:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 116:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 117:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 118:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 119:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 120:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 121:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 122:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 123:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 124:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 125:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 126:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 127:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 128:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 129:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 130:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 131:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 132:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 133:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 134:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 135:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 136:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 137:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 138:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 139:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 140:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 141:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 142:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 143:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 144:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 145:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 146:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 147:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 148:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 149:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 150:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 151:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 152:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 153:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 154:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 155:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 156:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 157:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 158:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 159:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 160:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 161:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 162:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 163:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 164:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 165:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 166:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 167:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 168:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 169:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 170:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 171:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 172:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 173:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 174:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 175:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 176:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 177:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 178:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 179:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 180:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 181:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 182:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 183:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 184:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 185:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 186:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 187:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 188:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 189:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 190:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 191:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 192:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 193:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 194:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 195:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 196:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 197:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 198:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 199:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 200:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 201:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 202:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 203:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 204:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 205:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 206:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 207:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 208:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 209:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 210:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 211:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 212:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 213:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 214:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 215:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 216:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 217:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 218:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 219:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 220:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 221:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 222:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 223:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 224:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 225:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 226:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 227:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 228:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 229:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 230:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 231:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 232:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 233:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 234:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 235:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 236:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 237:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 238:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 239:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 240:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 241:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 242:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 243:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 244:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 245:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 246:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 247:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 248:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 249:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 250:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 251:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 252:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 253:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 254:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 255:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 256:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 257:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 258:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 259:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 260:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 261:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 262:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
#   P2 Position: [0.05 0.05 0.05], Velocity: [0. 0. 0.]
# --------------------------------------------------
# Interaction
# Repel
# Step 263:
#   P1 Position: [-0.05 -0.05 -0.05], Velocity: [0. 0. 0.]
# ...
# --------------------------------------------------
# Step 214:
#   P1 Position: [-35.4 -35.4 -35.4], Velocity: [-5. -5. -5.]
#   P2 Position: [20.2 20.2 20.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 215:
#   P1 Position: [-35.65 -35.65 -35.65], Velocity: [-5. -5. -5.]
#   P2 Position: [20.325 20.325 20.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 216:
#   P1 Position: [-35.9 -35.9 -35.9], Velocity: [-5. -5. -5.]
#   P2 Position: [20.45 20.45 20.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 217:
#   P1 Position: [-36.15 -36.15 -36.15], Velocity: [-5. -5. -5.]
#   P2 Position: [20.575 20.575 20.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 218:
#   P1 Position: [-36.4 -36.4 -36.4], Velocity: [-5. -5. -5.]
#   P2 Position: [20.7 20.7 20.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 219:
#   P1 Position: [-36.65 -36.65 -36.65], Velocity: [-5. -5. -5.]
#   P2 Position: [20.825 20.825 20.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 220:
#   P1 Position: [-36.9 -36.9 -36.9], Velocity: [-5. -5. -5.]
#   P2 Position: [20.95 20.95 20.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 221:
#   P1 Position: [-37.15 -37.15 -37.15], Velocity: [-5. -5. -5.]
#   P2 Position: [21.075 21.075 21.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 222:
#   P1 Position: [-37.4 -37.4 -37.4], Velocity: [-5. -5. -5.]
#   P2 Position: [21.2 21.2 21.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 223:
#   P1 Position: [-37.65 -37.65 -37.65], Velocity: [-5. -5. -5.]
#   P2 Position: [21.325 21.325 21.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 224:
#   P1 Position: [-37.9 -37.9 -37.9], Velocity: [-5. -5. -5.]
#   P2 Position: [21.45 21.45 21.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 225:
#   P1 Position: [-38.15 -38.15 -38.15], Velocity: [-5. -5. -5.]
#   P2 Position: [21.575 21.575 21.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 226:
#   P1 Position: [-38.4 -38.4 -38.4], Velocity: [-5. -5. -5.]
#   P2 Position: [21.7 21.7 21.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 227:
#   P1 Position: [-38.65 -38.65 -38.65], Velocity: [-5. -5. -5.]
#   P2 Position: [21.825 21.825 21.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 228:
#   P1 Position: [-38.9 -38.9 -38.9], Velocity: [-5. -5. -5.]
#   P2 Position: [21.95 21.95 21.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 229:
#   P1 Position: [-39.15 -39.15 -39.15], Velocity: [-5. -5. -5.]
#   P2 Position: [22.075 22.075 22.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 230:
#   P1 Position: [-39.4 -39.4 -39.4], Velocity: [-5. -5. -5.]
#   P2 Position: [22.2 22.2 22.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 231:
#   P1 Position: [-39.65 -39.65 -39.65], Velocity: [-5. -5. -5.]
#   P2 Position: [22.325 22.325 22.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 232:
#   P1 Position: [-39.9 -39.9 -39.9], Velocity: [-5. -5. -5.]
#   P2 Position: [22.45 22.45 22.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 233:
#   P1 Position: [-40.15 -40.15 -40.15], Velocity: [-5. -5. -5.]
#   P2 Position: [22.575 22.575 22.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 234:
#   P1 Position: [-40.4 -40.4 -40.4], Velocity: [-5. -5. -5.]
#   P2 Position: [22.7 22.7 22.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 235:
#   P1 Position: [-40.65 -40.65 -40.65], Velocity: [-5. -5. -5.]
#   P2 Position: [22.825 22.825 22.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 236:
#   P1 Position: [-40.9 -40.9 -40.9], Velocity: [-5. -5. -5.]
#   P2 Position: [22.95 22.95 22.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 237:
#   P1 Position: [-41.15 -41.15 -41.15], Velocity: [-5. -5. -5.]
#   P2 Position: [23.075 23.075 23.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 238:
#   P1 Position: [-41.4 -41.4 -41.4], Velocity: [-5. -5. -5.]
#   P2 Position: [23.2 23.2 23.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 239:
#   P1 Position: [-41.65 -41.65 -41.65], Velocity: [-5. -5. -5.]
#   P2 Position: [23.325 23.325 23.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 240:
#   P1 Position: [-41.9 -41.9 -41.9], Velocity: [-5. -5. -5.]
#   P2 Position: [23.45 23.45 23.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 241:
#   P1 Position: [-42.15 -42.15 -42.15], Velocity: [-5. -5. -5.]
#   P2 Position: [23.575 23.575 23.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 242:
#   P1 Position: [-42.4 -42.4 -42.4], Velocity: [-5. -5. -5.]
#   P2 Position: [23.7 23.7 23.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 243:
#   P1 Position: [-42.65 -42.65 -42.65], Velocity: [-5. -5. -5.]
#   P2 Position: [23.825 23.825 23.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 244:
#   P1 Position: [-42.9 -42.9 -42.9], Velocity: [-5. -5. -5.]
#   P2 Position: [23.95 23.95 23.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 245:
#   P1 Position: [-43.15 -43.15 -43.15], Velocity: [-5. -5. -5.]
#   P2 Position: [24.075 24.075 24.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 246:
#   P1 Position: [-43.4 -43.4 -43.4], Velocity: [-5. -5. -5.]
#   P2 Position: [24.2 24.2 24.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 247:
#   P1 Position: [-43.65 -43.65 -43.65], Velocity: [-5. -5. -5.]
#   P2 Position: [24.325 24.325 24.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 248:
#   P1 Position: [-43.9 -43.9 -43.9], Velocity: [-5. -5. -5.]
#   P2 Position: [24.45 24.45 24.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 249:
#   P1 Position: [-44.15 -44.15 -44.15], Velocity: [-5. -5. -5.]
#   P2 Position: [24.575 24.575 24.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 250:
#   P1 Position: [-44.4 -44.4 -44.4], Velocity: [-5. -5. -5.]
#   P2 Position: [24.7 24.7 24.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 251:
#   P1 Position: [-44.65 -44.65 -44.65], Velocity: [-5. -5. -5.]
#   P2 Position: [24.825 24.825 24.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 252:
#   P1 Position: [-44.9 -44.9 -44.9], Velocity: [-5. -5. -5.]
#   P2 Position: [24.95 24.95 24.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 253:
#   P1 Position: [-45.15 -45.15 -45.15], Velocity: [-5. -5. -5.]
#   P2 Position: [25.075 25.075 25.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 254:
#   P1 Position: [-45.4 -45.4 -45.4], Velocity: [-5. -5. -5.]
#   P2 Position: [25.2 25.2 25.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 255:
#   P1 Position: [-45.65 -45.65 -45.65], Velocity: [-5. -5. -5.]
#   P2 Position: [25.325 25.325 25.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 256:
#   P1 Position: [-45.9 -45.9 -45.9], Velocity: [-5. -5. -5.]
#   P2 Position: [25.45 25.45 25.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 257:
#   P1 Position: [-46.15 -46.15 -46.15], Velocity: [-5. -5. -5.]
#   P2 Position: [25.575 25.575 25.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 258:
#   P1 Position: [-46.4 -46.4 -46.4], Velocity: [-5. -5. -5.]
#   P2 Position: [25.7 25.7 25.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 259:
#   P1 Position: [-46.65 -46.65 -46.65], Velocity: [-5. -5. -5.]
#   P2 Position: [25.825 25.825 25.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 260:
#   P1 Position: [-46.9 -46.9 -46.9], Velocity: [-5. -5. -5.]
#   P2 Position: [25.95 25.95 25.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 261:
#   P1 Position: [-47.15 -47.15 -47.15], Velocity: [-5. -5. -5.]
#   P2 Position: [26.075 26.075 26.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 262:
#   P1 Position: [-47.4 -47.4 -47.4], Velocity: [-5. -5. -5.]
#   P2 Position: [26.2 26.2 26.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 263:
#   P1 Position: [-47.65 -47.65 -47.65], Velocity: [-5. -5. -5.]
#   P2 Position: [26.325 26.325 26.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 264:
#   P1 Position: [-47.9 -47.9 -47.9], Velocity: [-5. -5. -5.]
#   P2 Position: [26.45 26.45 26.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 265:
#   P1 Position: [-48.15 -48.15 -48.15], Velocity: [-5. -5. -5.]
#   P2 Position: [26.575 26.575 26.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 266:
#   P1 Position: [-48.4 -48.4 -48.4], Velocity: [-5. -5. -5.]
#   P2 Position: [26.7 26.7 26.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 267:
#   P1 Position: [-48.65 -48.65 -48.65], Velocity: [-5. -5. -5.]
#   P2 Position: [26.825 26.825 26.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 268:
#   P1 Position: [-48.9 -48.9 -48.9], Velocity: [-5. -5. -5.]
#   P2 Position: [26.95 26.95 26.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 269:
#   P1 Position: [-49.15 -49.15 -49.15], Velocity: [-5. -5. -5.]
#   P2 Position: [27.075 27.075 27.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 270:
#   P1 Position: [-49.4 -49.4 -49.4], Velocity: [-5. -5. -5.]
#   P2 Position: [27.2 27.2 27.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 271:
#   P1 Position: [-49.65 -49.65 -49.65], Velocity: [-5. -5. -5.]
#   P2 Position: [27.325 27.325 27.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 272:
#   P1 Position: [-49.9 -49.9 -49.9], Velocity: [-5. -5. -5.]
#   P2 Position: [27.45 27.45 27.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 273:
#   P1 Position: [-50.15 -50.15 -50.15], Velocity: [-5. -5. -5.]
#   P2 Position: [27.575 27.575 27.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 274:
#   P1 Position: [-50.4 -50.4 -50.4], Velocity: [-5. -5. -5.]
#   P2 Position: [27.7 27.7 27.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 275:
#   P1 Position: [-50.65 -50.65 -50.65], Velocity: [-5. -5. -5.]
#   P2 Position: [27.825 27.825 27.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 276:
#   P1 Position: [-50.9 -50.9 -50.9], Velocity: [-5. -5. -5.]
#   P2 Position: [27.95 27.95 27.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 277:
#   P1 Position: [-51.15 -51.15 -51.15], Velocity: [-5. -5. -5.]
#   P2 Position: [28.075 28.075 28.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 278:
#   P1 Position: [-51.4 -51.4 -51.4], Velocity: [-5. -5. -5.]
#   P2 Position: [28.2 28.2 28.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 279:
#   P1 Position: [-51.65 -51.65 -51.65], Velocity: [-5. -5. -5.]
#   P2 Position: [28.325 28.325 28.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 280:
#   P1 Position: [-51.9 -51.9 -51.9], Velocity: [-5. -5. -5.]
#   P2 Position: [28.45 28.45 28.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 281:
#   P1 Position: [-52.15 -52.15 -52.15], Velocity: [-5. -5. -5.]
#   P2 Position: [28.575 28.575 28.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 282:
#   P1 Position: [-52.4 -52.4 -52.4], Velocity: [-5. -5. -5.]
#   P2 Position: [28.7 28.7 28.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 283:
#   P1 Position: [-52.65 -52.65 -52.65], Velocity: [-5. -5. -5.]
#   P2 Position: [28.825 28.825 28.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 284:
#   P1 Position: [-52.9 -52.9 -52.9], Velocity: [-5. -5. -5.]
#   P2 Position: [28.95 28.95 28.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 285:
#   P1 Position: [-53.15 -53.15 -53.15], Velocity: [-5. -5. -5.]
#   P2 Position: [29.075 29.075 29.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 286:
#   P1 Position: [-53.4 -53.4 -53.4], Velocity: [-5. -5. -5.]
#   P2 Position: [29.2 29.2 29.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 287:
#   P1 Position: [-53.65 -53.65 -53.65], Velocity: [-5. -5. -5.]
#   P2 Position: [29.325 29.325 29.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 288:
#   P1 Position: [-53.9 -53.9 -53.9], Velocity: [-5. -5. -5.]
#   P2 Position: [29.45 29.45 29.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 289:
#   P1 Position: [-54.15 -54.15 -54.15], Velocity: [-5. -5. -5.]
#   P2 Position: [29.575 29.575 29.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 290:
#   P1 Position: [-54.4 -54.4 -54.4], Velocity: [-5. -5. -5.]
#   P2 Position: [29.7 29.7 29.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 291:
#   P1 Position: [-54.65 -54.65 -54.65], Velocity: [-5. -5. -5.]
#   P2 Position: [29.825 29.825 29.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 292:
#   P1 Position: [-54.9 -54.9 -54.9], Velocity: [-5. -5. -5.]
#   P2 Position: [29.95 29.95 29.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 293:
#   P1 Position: [-55.15 -55.15 -55.15], Velocity: [-5. -5. -5.]
#   P2 Position: [30.075 30.075 30.075], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 294:
#   P1 Position: [-55.4 -55.4 -55.4], Velocity: [-5. -5. -5.]
#   P2 Position: [30.2 30.2 30.2], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 295:
#   P1 Position: [-55.65 -55.65 -55.65], Velocity: [-5. -5. -5.]
#   P2 Position: [30.325 30.325 30.325], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 296:
#   P1 Position: [-55.9 -55.9 -55.9], Velocity: [-5. -5. -5.]
#   P2 Position: [30.45 30.45 30.45], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 297:
#   P1 Position: [-56.15 -56.15 -56.15], Velocity: [-5. -5. -5.]
#   P2 Position: [30.575 30.575 30.575], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 298:
#   P1 Position: [-56.4 -56.4 -56.4], Velocity: [-5. -5. -5.]
#   P2 Position: [30.7 30.7 30.7], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 299:
#   P1 Position: [-56.65 -56.65 -56.65], Velocity: [-5. -5. -5.]
#   P2 Position: [30.825 30.825 30.825], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
# Step 300:
#   P1 Position: [-56.9 -56.9 -56.9], Velocity: [-5. -5. -5.]
#   P2 Position: [30.95 30.95 30.95], Velocity: [2.5 2.5 2.5]
# --------------------------------------------------
